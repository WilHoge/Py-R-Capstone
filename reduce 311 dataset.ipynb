# %%
import pandas as pd

# open download file
df_311 = pd.read_csv ('311_Service_Requests_from_2010_to_Present.csv')
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (11,12,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_311.shape
# Out:
# (5730709, 41)

# %%
df_311.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Open Data Channel Type',
#        'Park Facility Name', 'Park Borough', 'Vehicle Type',
#        'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %%
df_311.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    36256645  05/22/2017 01:04:13 PM  06/01/2017 05:49:36 PM    HPD
# 1    36256646  05/22/2017 05:30:54 PM  05/27/2017 11:22:47 AM    HPD
# 2    36258656  05/23/2017 05:01:02 PM  05/24/2017 11:42:10 AM    HPD
# 3    41770787  02/15/2019 09:32:11 AM  02/24/2019 02:05:25 AM    HPD
# 4    41773385  02/01/2019 10:46:34 AM  02/24/2019 02:05:24 AM    HPD
#
#                                          Agency Name          Complaint Type  \
# 0  Department of Housing Preservation and Develop...               APPLIANCE
# 1  Department of Housing Preservation and Develop...               APPLIANCE
# 2  Department of Housing Preservation and Develop...  HPD Literature Request
# 3  Department of Housing Preservation and Develop...               APPLIANCE
# 4  Department of Housing Preservation and Develop...              WATER LEAK
#
#             Descriptor         Location Type  Incident Zip  \
# ...

# %%
df_311.drop(['Unique Key', 'Agency', 'Agency Name',
       'Cross Street 1', 'Cross Street 2',
       'Intersection Street 1', 'Intersection Street 2', 'X Coordinate (State Plane)',
       'Y Coordinate (State Plane)', 'Resolution Description',
       'Park Facility Name', 'Park Borough', 'Vehicle Type',
       'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
       'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment', 'Location'], axis=1, inplace=True)

# %%
df_311.shape
# Out:
# (5730709, 21)

# %%
df_311.columns
# Out:
# Index(['Created Date', 'Closed Date', 'Complaint Type', 'Descriptor',
#        'Location Type', 'Incident Zip', 'Incident Address', 'Street Name',
#        'Address Type', 'City', 'Landmark', 'Facility Type', 'Status',
#        'Due Date', 'Resolution Action Updated Date', 'Community Board', 'BBL',
#        'Borough', 'Open Data Channel Type', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df_311.head()
# Out:
#              Created Date             Closed Date          Complaint Type  \
# 0  05/22/2017 01:04:13 PM  06/01/2017 05:49:36 PM               APPLIANCE
# 1  05/22/2017 05:30:54 PM  05/27/2017 11:22:47 AM               APPLIANCE
# 2  05/23/2017 05:01:02 PM  05/24/2017 11:42:10 AM  HPD Literature Request
# 3  02/15/2019 09:32:11 AM  02/24/2019 02:05:25 AM               APPLIANCE
# 4  02/01/2019 10:46:34 AM  02/24/2019 02:05:24 AM              WATER LEAK
#
#             Descriptor         Location Type  Incident Zip  \
# 0         REFRIGERATOR  RESIDENTIAL BUILDING       11207.0
# 1         REFRIGERATOR  RESIDENTIAL BUILDING       10010.0
# 2  The ABCs of Housing                   NaN           NaN
# 3   ELECTRIC/GAS RANGE  RESIDENTIAL BUILDING       11212.0
# 4           HEAVY FLOW  RESIDENTIAL BUILDING       11212.0
#
#           Incident Address          Street Name Address Type      City  ...  \
# 0  473 PENNSYLVANIA AVENUE  PENNSYLVANIA AVENUE      ADDRESS  BROOKLYN  ...
# ...

# %%
df_311.to_csv('311.csv')
