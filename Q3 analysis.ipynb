# %%
import pandas as pd
import numpy as np

# %%
df_bronx = pd.read_csv('PLUTO/BX_18v1.csv', low_memory=False)

# %%
print ("Bronx data shape:\n", df_bronx.shape)
print ("\n\nBronx data columns:\n", df_bronx.columns)
print ("\n\nBronx data types:\n", df_bronx.dtypes)
print ("\n\nBronx data nulls:\n", df_bronx.isnull().sum())
df_bronx.head()
# Out:
# Bronx data shape:
#  (89854, 87)
#
#
# Bronx data columns:
#  Index(['Borough', 'Block', 'Lot', 'CD', 'CT2010', 'CB2010', 'SchoolDist',
#        'Council', 'ZipCode', 'FireComp', 'PolicePrct', 'HealthCenterDistrict',
#        'HealthArea', 'SanitBoro', 'SanitDistrict', 'SanitSub', 'Address',
#        'ZoneDist1', 'ZoneDist2', 'ZoneDist3', 'ZoneDist4', 'Overlay1',
#        'Overlay2', 'SPDist1', 'SPDist2', 'SPDist3', 'LtdHeight', 'SplitZone',
#        'BldgClass', 'LandUse', 'Easements', 'OwnerType', 'OwnerName',
#        'LotArea', 'BldgArea', 'ComArea', 'ResArea', 'OfficeArea', 'RetailArea',
#        'GarageArea', 'StrgeArea', 'FactryArea', 'OtherArea', 'AreaSource',
#        'NumBldgs', 'NumFloors', 'UnitsRes', 'UnitsTotal', 'LotFront',
#        'LotDepth', 'BldgFront', 'BldgDepth', 'Ext', 'ProxCode', 'IrrLotCode',
#        'LotType', 'BsmtCode', 'AssessLand', 'AssessTot', 'ExemptLand',
#        'ExemptTot', 'YearBuilt', 'YearAlter1', 'YearAlter2', 'HistDist',
# ...

# %%
df_manhattan = pd.read_csv('PLUTO/MN_18v1.csv', low_memory=False)

# %%
print ("Manhattan data shape:\n", df_manhattan.shape)
print ("\n\nManhattan data columns:\n", df_manhattan.columns)
print ("\n\nManhattan data types:\n", df_manhattan.dtypes)
print ("\n\nManhattan data nulls:\n", df_manhattan.isnull().sum())
df_manhattan.head()
# Out:
# Manhattan data shape:
#  (42966, 87)
#
#
# Manhattan data columns:
#  Index(['Borough', 'Block', 'Lot', 'CD', 'CT2010', 'CB2010', 'SchoolDist',
#        'Council', 'ZipCode', 'FireComp', 'PolicePrct', 'HealthCenterDistrict',
#        'HealthArea', 'SanitBoro', 'SanitDistrict', 'SanitSub', 'Address',
#        'ZoneDist1', 'ZoneDist2', 'ZoneDist3', 'ZoneDist4', 'Overlay1',
#        'Overlay2', 'SPDist1', 'SPDist2', 'SPDist3', 'LtdHeight', 'SplitZone',
#        'BldgClass', 'LandUse', 'Easements', 'OwnerType', 'OwnerName',
#        'LotArea', 'BldgArea', 'ComArea', 'ResArea', 'OfficeArea', 'RetailArea',
#        'GarageArea', 'StrgeArea', 'FactryArea', 'OtherArea', 'AreaSource',
#        'NumBldgs', 'NumFloors', 'UnitsRes', 'UnitsTotal', 'LotFront',
#        'LotDepth', 'BldgFront', 'BldgDepth', 'Ext', 'ProxCode', 'IrrLotCode',
#        'LotType', 'BsmtCode', 'AssessLand', 'AssessTot', 'ExemptLand',
#        'ExemptTot', 'YearBuilt', 'YearAlter1', 'YearAlter2', 'HistDist',
# ...

# %% [markdown]
# ## 2. Step
#
# Merge and reduce datasets to what might be relevant to heating problems.

# %%
df_bronx = df_bronx[['Address', 'BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'Lot', 'LotArea', 'LotDepth', 'NumBldgs', 'UnitsRes',
                     'UnitsTotal', 'NumFloors', 'OfficeArea', 'ResArea', 'ResidFAR', 'RetailArea', 'YearBuilt', 'YearAlter1', 'ZipCode', 'YCoord', 'XCoord']]
df_bronx["Borough"] = 'BRONX'

df_manhattan = df_manhattan[['Address', 'BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'Lot', 'LotArea', 'LotDepth', 'NumBldgs', 'UnitsRes', 
                     'UnitsTotal', 'NumFloors', 'OfficeArea', 'ResArea', 'ResidFAR', 'RetailArea', 'YearBuilt', 'YearAlter1', 'ZipCode', 'YCoord', 'XCoord']]
df_manhattan["Borough"] = 'MANHATTAN'

df_buildings = pd.concat([df_bronx, df_manhattan],ignore_index=True)
df_buildings.shape
# Out:
# (132820, 23)

# %% [markdown]
# ## 3. Step
#
# Reduce complaints to addresses

# %%
df_311 = pd.read_csv("fhrw-4uyv.csv", parse_dates=True)
df_heat = df_311[(df_311["complaint_type"] == "HEATING") | (df_311["complaint_type"] == "HEAT/HOT WATER")]

# %%
# how do the number of complaints destribute over addresses

df_heat_adresses = df_heat.groupby(['borough','incident_address']).size().to_frame().reset_index()
df_heat_adresses.columns = ['Borough', 'Address', 'num_complaints']

df_heat_adresses["num_complaints"].describe()
# Out:
# count    164461.000000
# mean         12.276722
# std          64.696463
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           8.000000
# max       12360.000000
# Name: num_complaints, dtype: float64

# %%
# add classes for number of complaints

#df_heat_adresses["class_complaints"] = pd.cut(df_heat_adresses["num_complaints"], bins=[-1,0,10,100,2000,100000], labels=['none', 'low', 'medium', 'high', 'extreme'])

# use average of complaints per address for split between high and low
df_heat_adresses["class_complaints"] = pd.cut(df_heat_adresses["num_complaints"], bins=[-1,0,12,100000], labels=['none', 'low', 'high'])

# %%
df_heat_adresses.sort_values(by=["num_complaints"], ascending=False).head(10)
# Out:
#           Borough                   Address  num_complaints class_complaints
# 79180   MANHATTAN           34 ARDEN STREET           12360             high
# 115617     QUEENS     89-21 ELMHURST AVENUE            9854             high
# 14637       BRONX        3810 BAILEY AVENUE            7109             high
# 317         BRONX       1025 BOYNTON AVENUE            5761             high
# 64639    BROOKLYN           9511 SHORE ROAD            4194             high
# 7726        BRONX  2090 EAST TREMONT AVENUE            3665             high
# 20893       BRONX       888 GRAND CONCOURSE            2980             high
# 11941       BRONX         2968 PERRY AVENUE            2763             high
# 88859   MANHATTAN         97 SHERMAN AVENUE            2521             high
# 7646        BRONX       2074 WALLACE AVENUE            2473             high

# %% [markdown]
# ## 3. Step
#
# Mark addresses with complaints.

# %%
print ("Number of addresses with complaints about in the Bronx: ", len(df_heat_adresses[df_heat_adresses["Borough"] == "BRONX"]["Address"].unique()))
# Out:
# Number of addresses with complaints about in the Bronx:  21976

# %%
print ("Rows with no address in Houses dataset: ", df_buildings["Address"].isnull().sum())
df_buildings.dropna(subset=["Address"], inplace=True)

print ("Rows with no address in complaints dataset: ", df_heat_adresses["Address"].isnull().sum())
df_heat_adresses.dropna(subset=["Address"], inplace=True)
# Out:
# Rows with no address in Houses dataset:  118
# Rows with no address in complaints dataset:  0

# %%
# merge datasets and fill nan with 0,none

df_buildings2 = pd.merge(df_buildings, df_heat_adresses, how='left', on=['Borough', 'Address'])
df_buildings2.fillna(value={'num_complaints' : 0, 'class_complaints' : 'none'}, inplace=True)

# %%
# Some address are appearing multiple times

print (df_buildings2.groupby(['Borough','Address', 'class_complaints']).size().sort_values(ascending=False))

print ("\n\nLook at the records for WHITE PLAINS ROAD\n")
df_buildings2[df_buildings2['Address']=='WHITE PLAINS ROAD'].tail(5)
# Out:
# Borough    Address                 class_complaints
# BRONX      SHORE DRIVE             none                42
#            PALISADE AVENUE         none                37
#            WHITE PLAINS ROAD       none                35
# MANHATTAN  F D R DRIVE             none                35
# BRONX      PARK AVENUE             none                35
#            BRUCKNER BOULEVARD      none                34
#            MAJ WM DEEGAN BLVD      none                32
#            WEST 246 STREET         none                29
#            SEDGWICK AVENUE         none                27
# MANHATTAN  MARGINAL STREET         none                27
# BRONX      POST ROAD               none                22
# MANHATTAN  RIVERSIDE DRIVE         none                22
# BRONX      3 AVENUE                none                21
#            UNIVERSITY AVENUE       none                21
#            BRONX RIVER AVENUE      none                20
# ...

# %%
# drop records with duplicated addresses as they are no addresses with complaints

print ("Number of addresses including duplicate rows: ", len(df_buildings2))
df_buildings2.drop_duplicates(subset="Address", keep=False, inplace=True)
print ("Number of addresses without duplicate rows: ", len(df_buildings2))
# Out:
# Number of addresses including duplicate rows:  132702
# Number of addresses without duplicate rows:  128183

# %% [markdown]
# ## 4. Step
#
# Analyzing correlations

# %%
df_buildings3 = pd.concat([df_buildings2, pd.get_dummies(df_buildings2.class_complaints)],axis=1)

# df_buildings3[['NumFloors', 'UnitsRes', 'YearBuilt','YearAlter1','none', 'low', 'medium', 'high', 'extreme']].corr('pearson')
df_buildings3[['NumFloors', 'UnitsRes', 'YearBuilt','YearAlter1','none', 'low', 'high']].corr('pearson')
# Out:
#             NumFloors  UnitsRes  YearBuilt  YearAlter1      none       low  \
# NumFloors    1.000000  0.324941   0.158394    0.228670 -0.164738  0.098399
# UnitsRes     0.324941  1.000000   0.024130    0.061027 -0.106642  0.041997
# YearBuilt    0.158394  0.024130   1.000000    0.089027 -0.082451  0.063236
# YearAlter1   0.228670  0.061027   0.089027    1.000000 -0.176701  0.114389
# none        -0.164738 -0.106642  -0.082451   -0.176701  1.000000 -0.805143
# low          0.098399  0.041997   0.063236    0.114389 -0.805143  1.000000
# high         0.131156  0.116782   0.045096    0.127688 -0.490831 -0.121535
#
#                 high
# NumFloors   0.131156
# UnitsRes    0.116782
# YearBuilt   0.045096
# YearAlter1  0.127688
# none       -0.490831
# low        -0.121535
# high        1.000000

# %% [markdown]
# ## 5. Step
#
# Try to find a model to predict complaints from house attributes

# %%
# setting up training

#!pip install sklearn

from sklearn.model_selection import train_test_split

all_features = ['BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'Lot', 'LotArea', 'LotDepth', 'NumBldgs', 'UnitsRes', 'UnitsTotal', 'NumFloors', 'OfficeArea', 'ResArea', 'ResidFAR', 'RetailArea', 'YearBuilt', 'YearAlter1']
some_features = ['NumFloors', 'UnitsRes', 'UnitsTotal', 'YearBuilt','YearAlter1']
few_features = ['NumFloors', 'UnitsRes', 'UnitsTotal']

# split dataset
X_trainset, X_testset, y_trainset, y_testset = train_test_split(df_buildings2[all_features], df_buildings2['class_complaints'], test_size=0.3, random_state=3)

print (X_trainset.shape, X_testset.shape, y_trainset.shape, y_testset.shape)
# Out:
# (89728, 18) (38455, 18) (89728,) (38455,)

# %%
X_trainset.isna().sum()
# Out:
# BldgArea      0
# BldgDepth     0
# BuiltFAR      0
# CommFAR       0
# FacilFAR      0
# Lot           0
# LotArea       0
# LotDepth      0
# NumBldgs      0
# UnitsRes      0
# UnitsTotal    0
# NumFloors     0
# OfficeArea    0
# ResArea       0
# ResidFAR      0
# RetailArea    0
# YearBuilt     0
# YearAlter1    0
# dtype: int64

# %%
# try decision tree

from sklearn.tree import DecisionTreeClassifier

houseTree = DecisionTreeClassifier(criterion="entropy", max_depth = 6, max_leaf_nodes=10)

houseTree.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=6,
#             max_features=None, max_leaf_nodes=10,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# importance of features

xx = X_trainset.columns.to_frame().reset_index(drop=True)
xx ['prob'] = houseTree.feature_importances_
xx.sort_values(by='prob', ascending=False)
# Out:
#              0      prob
# 9     UnitsRes  0.809585
# 10  UnitsTotal  0.088839
# 11   NumFloors  0.039011
# 13     ResArea  0.032149
# 6      LotArea  0.010212
# 5          Lot  0.010127
# 0     BldgArea  0.010076
# 7     LotDepth  0.000000
# 8     NumBldgs  0.000000
# 1    BldgDepth  0.000000
# 4     FacilFAR  0.000000
# 3      CommFAR  0.000000
# 12  OfficeArea  0.000000
# 2     BuiltFAR  0.000000
# 14    ResidFAR  0.000000
# 15  RetailArea  0.000000
# 16   YearBuilt  0.000000
# 17  YearAlter1  0.000000

# %%
predTree = houseTree.predict(X_testset)

# %%
from sklearn import metrics

print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_testset, predTree))
print("DecisionTrees's Recall: ", metrics.recall_score(y_testset, predTree, average='weighted'))
print("DecisionTrees's F1: ", metrics.f1_score(y_testset, predTree, average='weighted'))
# Out:
# DecisionTrees's Accuracy:  0.7933168638668574
# DecisionTrees's Recall:  0.7933168638668574
# DecisionTrees's F1:  0.7498839141755315

# %%
#!conda install -c conda-forge pydotplus -y
#!conda install -c conda-forge python-graphviz -y

# %%
from sklearn.externals.six import StringIO
import pydotplus
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn import tree
# %matplotlib inline 

dot_data = StringIO()
filename = "housetree.png"
featureNames = X_trainset.columns
targetNames = df_buildings2['class_complaints'].unique().tolist()
out=tree.export_graphviz(houseTree,feature_names=featureNames, out_file=dot_data, class_names= np.unique(y_trainset), filled=True,  special_characters=True,rotate=False)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png(filename)
img = mpimg.imread(filename)
plt.figure(figsize=(100, 200))
plt.imshow(img,interpolation='nearest')

# %%
pd.Series(predTree).to_frame().groupby(by=0).size()
# Out:
# 0
# high     2507
# low      1641
# none    34307
# dtype: int64

# %%
# try random forrest

from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_jobs=2, n_estimators=100, random_state=0)
clf.fit(X_trainset,y_trainset)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=2,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
xx = X_trainset.columns.to_frame().reset_index(drop=True)
xx ['prob'] = clf.feature_importances_
xx.sort_values(by='prob', ascending=False)
# Out:
#              0      prob
# 5          Lot  0.119093
# 13     ResArea  0.107554
# 2     BuiltFAR  0.091236
# 0     BldgArea  0.088125
# 10  UnitsTotal  0.081390
# 9     UnitsRes  0.080412
# 6      LotArea  0.076275
# 1    BldgDepth  0.068865
# 7     LotDepth  0.058315
# 16   YearBuilt  0.056893
# 11   NumFloors  0.033409
# 14    ResidFAR  0.033154
# 17  YearAlter1  0.030047
# 4     FacilFAR  0.022832
# 15  RetailArea  0.021189
# 3      CommFAR  0.012491
# 8     NumBldgs  0.010873
# 12  OfficeArea  0.007848

# %%
predRF = clf.predict(X_testset)
print("Random Forrest's Accuracy: ", metrics.accuracy_score(y_testset, predRF))
print("Random Forrest's Recall: ", metrics.recall_score(y_testset, predRF, average='weighted'))
print("Random Forrest's F1: ", metrics.f1_score(y_testset, predRF, average='weighted'))
# Out:
# Random Forrest's Accuracy:  0.7934988948121181
# Random Forrest's Recall:  0.7934988948121181
# Random Forrest's F1:  0.7734064764325091

# %%
print (pd.Series(predRF).to_frame().groupby(by=0).size())
print (y_testset.to_frame().groupby(by='class_complaints').size())
# Out:
# 0
# high     2293
# low      3833
# none    32329
# dtype: int64
# class_complaints
# none    29505
# low      6341
# high     2609
# dtype: int64

# %%
df_buildings4 = df_buildings2.reset_index()
df_buildings4['predDT'] = pd.Series(houseTree.predict(df_buildings4[all_features]))
df_buildings4['predDTprob'] = houseTree.predict_proba(df_buildings4[all_features]).tolist()
df_buildings4['predRF'] = pd.Series(clf.predict(df_buildings4[all_features]))
df_buildings4['predRFprob'] = clf.predict_proba(df_buildings4[all_features]).tolist()

# %%
df_buildings4[(df_buildings4['predRF'] == 'high') | (df_buildings4['class_complaints'] == 'high')]
# Out:
#          index                 Address  BldgArea  BldgDepth  BuiltFAR  \
# 4            4  148 BRUCKNER BOULEVARD      8595       70.0      4.58
# 24          27  147 BRUCKNER BOULEVARD     11500       96.0      4.60
# 53          56         202 BROWN PLACE     18837       81.0      4.19
# 55          58        205 BROOK AVENUE     16466       87.0      4.12
# 66          70     512 EAST 138 STREET     19126       90.0      5.17
# 67          71     514 EAST 138 STREET     15666       87.0      4.02
# 68          72     518 EAST 138 STREET     15666       87.0      4.02
# 70          74     526 EAST 138 STREET     20976       87.0      4.20
# 71          75     530 EAST 138 STREET     20976       87.0      4.20
# 72          76     534 EAST 138 STREET     20976       87.0      4.20
# 78          82      219 ST ANNS AVENUE     10368       96.0      3.77
# 82          86     543 EAST 137 STREET     11380       95.0      4.55
# ...

# %%
from sklearn import preprocessing

all_features = ['BldgArea', 'BldgDepth', 'BuiltFAR', 'CommFAR', 'FacilFAR', 'Lot', 'LotArea', 'LotDepth', 'NumBldgs', 'UnitsRes', 'UnitsTotal', 'NumFloors', 'OfficeArea', 'ResArea', 'ResidFAR', 'RetailArea', 'YearBuilt', 'YearAlter1']
some_features = ['NumFloors', 'UnitsRes', 'UnitsTotal', 'YearBuilt','YearAlter1']
few_features = ['NumFloors', 'UnitsRes', 'UnitsTotal']

# preprocessing
df_buildings2pre = preprocessing.StandardScaler().fit(df_buildings2[all_features]).transform(df_buildings2[all_features])

# split dataset
X_trainset, X_testset, y_trainset, y_testset = train_test_split(df_buildings2pre, df_buildings2['class_complaints'], test_size=0.3, random_state=3)

print (X_trainset.shape, X_testset.shape, y_trainset.shape, y_testset.shape)
# Out:
# (89728, 18) (38455, 18) (89728,) (38455,)
# /opt/conda/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_trainset,y_trainset)
LR
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='liblinear',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
predLR = LR.predict(X_testset)
print("Logistic Regression's Accuracy: ", metrics.accuracy_score(y_testset, predLR))
print("Logistic Regression's Recall: ", metrics.recall_score(y_testset, predLR, average='weighted'))
print("Logistic Regression's F1: ", metrics.f1_score(y_testset, predLR, average='weighted'))
# Out:
# Logistic Regression's Accuracy:  0.7619815368612665
# Logistic Regression's Recall:  0.7619815368612665
# Logistic Regression's F1:  0.676150444262664

# %%
LR.coef_
# Out:
# array([[-7.22518348e-01,  9.68283734e-01,  2.82063303e-01,
#         -6.89447480e-01,  5.01090035e-01, -1.97015161e-01,
#         -1.94599450e-01, -5.86922582e-01, -3.71598914e-01,
#          5.38621240e-01,  1.36446846e-01,  2.47049551e-02,
#         -4.92196012e-01,  2.86474661e-01, -2.03273503e-01,
#         -5.13686517e-01,  1.03505308e-01,  1.34702372e-01],
#        [-1.89400878e-01,  2.87028211e-01,  3.62952185e-02,
#         -2.81625462e-01,  2.01929059e-01, -3.98567722e-02,
#          5.91867275e-04, -2.16359042e-01,  1.43379670e-02,
#          1.88097764e-01, -4.83306220e-02,  1.41273302e-01,
#         -9.01827151e-03, -8.02938773e-02,  1.47494360e-01,
#         -3.89988448e-02,  1.80130580e-01,  1.06187686e-01],
#        [ 5.27845975e-01, -6.94222496e-01, -2.14458519e-01,
#          4.91621996e-01, -3.32547451e-01,  1.08564144e-01,
#          5.46064920e-02,  4.19992055e-01,  1.54383792e-01,
#         -7.85503077e-01, -6.82419945e-02, -1.54096874e-01,
# ...

# %%
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_testset, predLR)
# Out:
# 0.7619815368612665
