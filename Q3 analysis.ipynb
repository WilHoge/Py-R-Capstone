# %%
import pandas as pd

# %%
df_bronx = pd.read_csv('PLUTO/BX_18v1.csv', low_memory=False)

# %%
print ("Bronx data shape:\n", df_bronx.shape)
print ("\n\nBronx data columns:\n", df_bronx.columns)
print ("\n\nBronx data types:\n", df_bronx.dtypes)
print ("\n\nBronx data nulls:\n", df_bronx.isnull().sum())
df_bronx.head()
# Out:
# Bronx data shape:
#  (89854, 87)
#
#
# Bronx data columns:
#  Index(['Borough', 'Block', 'Lot', 'CD', 'CT2010', 'CB2010', 'SchoolDist',
#        'Council', 'ZipCode', 'FireComp', 'PolicePrct', 'HealthCenterDistrict',
#        'HealthArea', 'SanitBoro', 'SanitDistrict', 'SanitSub', 'Address',
#        'ZoneDist1', 'ZoneDist2', 'ZoneDist3', 'ZoneDist4', 'Overlay1',
#        'Overlay2', 'SPDist1', 'SPDist2', 'SPDist3', 'LtdHeight', 'SplitZone',
#        'BldgClass', 'LandUse', 'Easements', 'OwnerType', 'OwnerName',
#        'LotArea', 'BldgArea', 'ComArea', 'ResArea', 'OfficeArea', 'RetailArea',
#        'GarageArea', 'StrgeArea', 'FactryArea', 'OtherArea', 'AreaSource',
#        'NumBldgs', 'NumFloors', 'UnitsRes', 'UnitsTotal', 'LotFront',
#        'LotDepth', 'BldgFront', 'BldgDepth', 'Ext', 'ProxCode', 'IrrLotCode',
#        'LotType', 'BsmtCode', 'AssessLand', 'AssessTot', 'ExemptLand',
#        'ExemptTot', 'YearBuilt', 'YearAlter1', 'YearAlter2', 'HistDist',
#        'Landmark', 'BuiltFAR', 'ResidFAR', 'CommFAR', 'FacilFAR', 'BoroCode',
#        'BBL', 'CondoNo', 'Tract2010', 'XCoord', 'YCoord', 'ZoneMap', 'ZMCode',
#        'Sanborn', 'TaxMap', 'EDesigNum', 'APPBBL', 'APPDate', 'PLUTOMapID',
#        'FIRM07_FLAG', 'PFIRM15_FLAG', 'Version'],
#       dtype='object')
#
#
# Bronx data types:
#  Borough                  object
# Block                     int64
# Lot                       int64
# CD                        int64
# CT2010                  float64
# CB2010                  float64
# SchoolDist              float64
# Council                 float64
# ZipCode                 float64
# FireComp                 object
# PolicePrct              float64
# HealthCenterDistrict    float64
# HealthArea              float64
# SanitBoro               float64
# SanitDistrict           float64
# SanitSub                 object
# Address                  object
# ZoneDist1                object
# ZoneDist2                object
# ZoneDist3                object
# ZoneDist4                object
# Overlay1                 object
# Overlay2                 object
# SPDist1                  object
# SPDist2                 float64
# SPDist3                 float64
# LtdHeight               float64
# SplitZone                object
# BldgClass                object
# LandUse                 float64
#                          ...
# AssessLand                int64
# AssessTot                 int64
# ExemptLand                int64
# ExemptTot                 int64
# YearBuilt                 int64
# YearAlter1                int64
# YearAlter2                int64
# HistDist                 object
# Landmark                 object
# BuiltFAR                float64
# ResidFAR                float64
# CommFAR                 float64
# FacilFAR                float64
# BoroCode                  int64
# BBL                       int64
# CondoNo                   int64
# Tract2010                 int64
# XCoord                  float64
# YCoord                  float64
# ZoneMap                  object
# ZMCode                   object
# Sanborn                  object
# TaxMap                  float64
# EDesigNum                object
# APPBBL                  float64
# APPDate                  object
# PLUTOMapID                int64
# FIRM07_FLAG             float64
# PFIRM15_FLAG            float64
# Version                  object
# Length: 87, dtype: object
#
#
# Bronx data nulls:
#  Borough                     0
# Block                       0
# Lot                         0
# CD                          0
# CT2010                    407
# CB2010                   2512
# SchoolDist                159
# Council                   205
# ZipCode                   329
# FireComp                  286
# PolicePrct                162
# HealthCenterDistrict      127
# HealthArea                224
# SanitBoro                 619
# SanitDistrict             616
# SanitSub                 1065
# Address                    69
# ZoneDist1                  59
# ZoneDist2               87301
# ZoneDist3               89820
# ZoneDist4               89852
# Overlay1                81027
# Overlay2                89758
# SPDist1                 85252
# SPDist2                 89854
# SPDist3                 89854
# LtdHeight               89854
# SplitZone                  66
# BldgClass                  66
# LandUse                   414
#                         ...
# AssessLand                  0
# AssessTot                   0
# ExemptLand                  0
# ExemptTot                   0
# YearBuilt                   0
# YearAlter1                  0
# YearAlter2                  0
# HistDist                89000
# Landmark                89743
# BuiltFAR                    0
# ResidFAR                    0
# CommFAR                     0
# FacilFAR                    0
# BoroCode                    0
# BBL                         0
# CondoNo                     0
# Tract2010                   0
# XCoord                   3259
# YCoord                   3259
# ZoneMap                    37
# ZMCode                  88166
# Sanborn                   119
# TaxMap                    119
# EDesigNum               88384
# APPBBL                     66
# APPDate                 78885
# PLUTOMapID                  0
# FIRM07_FLAG             86343
# PFIRM15_FLAG            86522
# Version                     0
# Length: 87, dtype: int64
#   Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      BX   2260    1  201    19.0  1022.0         7.0      8.0  10454.0
# 1      BX   2260    4  201    19.0  1022.0         7.0      8.0  10454.0
# 2      BX   2260   10  201    19.0  1022.0         7.0      8.0  10454.0
# 3      BX   2260   17  201    19.0  1022.0         7.0      8.0  10454.0
# 4      BX   2260   18  201    19.0  1022.0         7.0      8.0  10454.0
#
#   FireComp  ...  ZMCode  Sanborn   TaxMap  EDesigNum  APPBBL APPDate  \
# 0     L029  ...     NaN  209S016  20901.0      E-143     0.0     NaN
# 1     L029  ...     NaN  209S016  20901.0      E-143     0.0     NaN
# 2     L029  ...     NaN  209S016  20901.0      E-143     0.0     NaN
# 3     L029  ...     NaN  209S016  20901.0      E-143     0.0     NaN
# 4     L029  ...     NaN  209S016  20901.0      E-143     0.0     NaN
#
#   PLUTOMapID FIRM07_FLAG PFIRM15_FLAG Version
# 0          1         NaN          NaN    18V1
# 1          1         NaN          NaN    18V1
# 2          1         NaN          NaN    18V1
# 3          1         NaN          NaN    18V1
# 4          1         NaN          NaN    18V1
#
# [5 rows x 87 columns]

# %% [markdown]
# ## 2. Step
#
# Reduce datasets to what might be relevant to heating problems.

# %%
df_bronx = df_bronx[['Borough', 'Address', 'NumBldgs', 'NumFloors', 'UnitsRes', 'UnitsTotal',
                    'YearBuilt', 'YearAlter1', 'YearAlter2']]

# %% [markdown]
# ## 3. Step
#
# Reduce complaints to addresses

# %%
df_311 = pd.read_csv("fhrw-4uyv.csv", parse_dates=True)
df_heat = df_311[(df_311["complaint_type"] == "HEATING") | (df_311["complaint_type"] == "HEAT/HOT WATER")]

# %%
df_heat_adresses = df_heat.groupby(['borough','incident_address']).size().to_frame().reset_index()
df_heat_adresses.columns = ['Borough', 'Address', 'num_complaints']
df_heat_adresses["class_complaints"] = pd.cut(df_heat_adresses["num_complaints"], bins=[0,10,100,100000], labels=['low', 'medium', 'high'])

# %%
df_heat_adresses["num_complaints"].describe()
# Out:
# count    164461.000000
# mean         12.276722
# std          64.696463
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           8.000000
# max       12360.000000
# Name: num_complaints, dtype: float64

# %%
df_heat_adresses.sort_values(by=["num_complaints"], ascending=False).head(10)
# Out:
#           Borough                   Address  num_complaints class_complaints
# 79180   MANHATTAN           34 ARDEN STREET           12360             high
# 115617     QUEENS     89-21 ELMHURST AVENUE            9854             high
# 14637       BRONX        3810 BAILEY AVENUE            7109             high
# 317         BRONX       1025 BOYNTON AVENUE            5761             high
# 64639    BROOKLYN           9511 SHORE ROAD            4194             high
# 7726        BRONX  2090 EAST TREMONT AVENUE            3665             high
# 20893       BRONX       888 GRAND CONCOURSE            2980             high
# 11941       BRONX         2968 PERRY AVENUE            2763             high
# 88859   MANHATTAN         97 SHERMAN AVENUE            2521             high
# 7646        BRONX       2074 WALLACE AVENUE            2473             high

# %% [markdown]
# ## 3. Step
#
# Mark addresses with complaints.

# %%
df_bronx["Borough"] = 'BRONX'

# %%
print ("Number of addresses with complaints about in the Bronx: ", len(df_heat_adresses[df_heat_adresses["Borough"] == "BRONX"]["Address"].unique()))
# Out:
# Number of addresses with complaints about in the Bronx:  21976

# %%
print ("Rows with no address in Bronx dataset: ", df_bronx["Address"].isnull().sum())
df_bronx.dropna(subset=["Address"], inplace=True)

print ("Rows with no address in complaints dataset: ", df_heat_adresses["Address"].isnull().sum())
df_heat_adresses.dropna(subset=["Address"], inplace=True)
# Out:
# Rows with no address in Bronx dataset:  0
# Rows with no address in complaints dataset:  0

# %%
df_bronx2 = pd.merge(df_bronx, df_heat_adresses, how='left', on=['Borough', 'Address'])

# %%
df_bronx2.head(20)
# Out:
#    Borough                 Address  NumBldgs  NumFloors  UnitsRes  UnitsTotal  \
# 0    BRONX  122 BRUCKNER BOULEVARD         1        0.0         0           0
# 1    BRONX  126 BRUCKNER BOULEVARD         2        1.0         0           1
# 2    BRONX  138 BRUCKNER BOULEVARD         1        2.0         0           1
# 3    BRONX  144 BRUCKNER BOULEVARD         1        5.0        15          15
# 4    BRONX  148 BRUCKNER BOULEVARD         1        5.0         8          10
# 5    BRONX          ST ANNS AVENUE         0        0.0         0           0
# 6    BRONX     519 EAST 132 STREET         2        1.0         0           2
# 7    BRONX     517 EAST 132 STREET         1        3.0         0           1
# 8    BRONX          LINCOLN AVENUE         0        0.0         0           0
# 9    BRONX         EAST 132 STREET         0        0.0         0           0
# 10   BRONX     290 EAST 132 STREET         1        1.0         0           1
# 11   BRONX         EAST 132 STREET         0        0.0         0           0
# 12   BRONX     180 EAST 132 STREET         0        0.0         0           0
# 13   BRONX     550 EAST 132 STREET         1        1.0         0           1
# 14   BRONX      500 ST ANNS AVENUE         0        0.0         0           0
# 15   BRONX     496 EAST 134 STREET         1        1.0         0           1
# 16   BRONX     500 EAST 134 STREET         1        5.0         0           1
# 17   BRONX        119 BROOK AVENUE         1        1.0         0           1
# 18   BRONX  115 BRUCKNER BOULEVARD         2        1.0         0           2
# 19   BRONX     510 EAST 134 STREET         0        0.0         0           0
#
#     YearBuilt  YearAlter1  YearAlter2  num_complaints class_complaints
# 0           0           0           0             NaN              NaN
# 1        1931        1994           0             NaN              NaN
# 2        1931           0           0             NaN              NaN
# 3        1931        2001           0             2.0              low
# 4        1920        2009           0            13.0           medium
# 5           0           0           0             NaN              NaN
# 6        1931           0           0             NaN              NaN
# 7        1931           0           0             NaN              NaN
# 8           0           0           0             NaN              NaN
# 9           0           0           0             NaN              NaN
# 10       1931           0           0             NaN              NaN
# 11          0           0           0             NaN              NaN
# 12          0           0           0             NaN              NaN
# 13       1967           0           0             NaN              NaN
# 14          0           0           0             NaN              NaN
# 15       1963           0           0             NaN              NaN
# 16       1931        2016           0             NaN              NaN
# 17       1931        1986           0             NaN              NaN
# 18       1973        1988        1998             NaN              NaN
# 19          0           0           0             NaN              NaN
